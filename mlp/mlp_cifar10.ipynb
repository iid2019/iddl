# %%
# For inline plotting
# %matplotlib inline

# For auto reloading
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # CIFAR10 dataset with MLP
#
# [reference](https://github.com/CSCfi/machine-learning-scripts/blob/master/notebooks/pytorch-mnist-mlp.ipynb)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms

import numpy as np
import matplotlib.pyplot as plt

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print('Using PyTorch version:', torch.__version__, ' Device:', device)
# Out:
# Using PyTorch version: 1.3.1  Device: cuda

# %% [markdown]
# ## Data
#
# Next we'll load the CIFAR10 data. First time we may have to download the data, which can take a while.
#
# Note that we are here using the CIFAR10 test data for *validation*, instead of for testing the final model.

# %%
batch_size = 32

train_dataset = datasets.CIFAR10('./data', 
                               train=True, 
                               download=True, 
                               transform=transforms.ToTensor())

validation_dataset = datasets.CIFAR10('./data', 
                                    train=False, 
                                    transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, 
                                                batch_size=batch_size, 
                                                shuffle=False)
# Out:
# Files already downloaded and verified

# %% [markdown]
# The train and test data are provided via data loaders that provide iterators over the datasets. The first element of training data (`X_train`) is a 4th-order tensor of size (`batch_size`, 3, 32, 32), i.e. it consists of a batch of images of size $3 \times 32 \times 32$ pixels. `y_train` is a vector containing the correct classes ("0", "1", ..., "9") for each training digit.

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 3, 32, 32]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %% [markdown]
# Here are the first 10 training digits:

# %% [markdown]
# ## MLP network definition
#
# Let's define the network as a Python class.  We have to write the `__init__()` and `forward()` methods, and PyTorch will automatically generate a `backward()` method for computing the gradients for the backward pass.
#
# Finally, we define an optimizer to update the model parameters based on the computed gradients.  We select *stochastic gradient descent (with momentum)* as the optimization algorithm, and set *learning rate* to 0.01.  Note that there are [several different options](http://pytorch.org/docs/optim.html#algorithms) for the optimizer in PyTorch that we could use instead of *SGD*.

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3*32*32, 49)
        self.fc1_drop = nn.Dropout(0.2)
        self.fc2 = nn.Linear(49, 56)
        self.fc2_drop = nn.Dropout(0.2)
        self.fc3 = nn.Linear(56, 10)

    def forward(self, x):
        x = x.view(-1, 3*32*32)
        x = F.relu(self.fc1(x))
        x = self.fc1_drop(x)
        x = F.relu(self.fc2(x))
        x = self.fc2_drop(x)
        return F.log_softmax(self.fc3(x), dim=1)

model = Net().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=3072, out_features=49, bias=True)
#   (fc1_drop): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=49, out_features=56, bias=True)
#   (fc2_drop): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=56, out_features=10, bias=True)
# )

# %% [markdown]
# ## Learning
#
# Let's now define functions to `train()` and `validate()` the model.

# %%
def train(epoch, log_interval=200):
    # Set model to training mode
    model.train()
    
    # Loop over each batch from the training set
    for batch_idx, (data, target) in enumerate(train_loader):
        # Copy data to GPU if needed
        data = data.to(device)
        target = target.to(device)

        # Zero gradient buffers
        optimizer.zero_grad() 
        
        # Pass data through the network
        output = model(data)

        # Calculate loss
        loss = criterion(output, target)

        # Backpropagate
        loss.backward()
        
        # Update weights
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

# %%
def validate(loss_vector, accuracy_vector):
    model.eval()
    val_loss, correct = 0, 0
    for data, target in validation_loader:
        data = data.to(device)
        target = target.to(device)
        output = model(data)
        val_loss += criterion(output, target).data.item()
        pred = output.data.max(1)[1] # get the index of the max log-probability
        correct += pred.eq(target.data).cpu().sum()

    val_loss /= len(validation_loader)
    loss_vector.append(val_loss)

    accuracy = 100. * correct.to(torch.float32) / len(validation_loader.dataset)
    accuracy_vector.append(accuracy)
    
    print('\nValidation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        val_loss, correct, len(validation_loader.dataset), accuracy))

# %% [markdown]
# Now we are ready to train our model using the `train()` function.  An *epoch* means one pass through the whole training data. After each epoch, we evaluate the model using `validate()`.

# %%
# %%time
epochs = 100

lossv, accv = [], []
for epoch in range(1, epochs + 1):
    train(epoch, log_interval=1000)
    validate(lossv, accv)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.324616
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 1.905424
#
# Validation set: Average loss: 1.8488, Accuracy: 3353/10000 (34%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.928063
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 1.925148
#
# Validation set: Average loss: 1.7497, Accuracy: 3719/10000 (37%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 2.240911
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 1.781989
#
# Validation set: Average loss: 1.7018, Accuracy: 3999/10000 (40%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 2.129349
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 2.034743
#
# Validation set: Average loss: 1.7138, Accuracy: 3820/10000 (38%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.637108
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 1.675241
#
# Validation set: Average loss: 1.6833, Accuracy: 3951/10000 (40%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.746298
# Train Epoch: 6 [32000/50000 (64%)]	Loss: 1.667555
#
# Validation set: Average loss: 1.6191, Accuracy: 4226/10000 (42%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.825328
# Train Epoch: 7 [32000/50000 (64%)]	Loss: 1.706615
#
# Validation set: Average loss: 1.5903, Accuracy: 4323/10000 (43%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.711495
# Train Epoch: 8 [32000/50000 (64%)]	Loss: 1.644099
#
# Validation set: Average loss: 1.5788, Accuracy: 4361/10000 (44%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.495329
# Train Epoch: 9 [32000/50000 (64%)]	Loss: 1.570839
#
# Validation set: Average loss: 1.5537, Accuracy: 4419/10000 (44%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.619023
# Train Epoch: 10 [32000/50000 (64%)]	Loss: 1.293790
#
# Validation set: Average loss: 1.5592, Accuracy: 4357/10000 (44%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.659632
# Train Epoch: 11 [32000/50000 (64%)]	Loss: 1.794039
#
# Validation set: Average loss: 1.5479, Accuracy: 4498/10000 (45%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.685840
# Train Epoch: 12 [32000/50000 (64%)]	Loss: 2.024833
#
# Validation set: Average loss: 1.5230, Accuracy: 4602/10000 (46%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 2.192338
# Train Epoch: 13 [32000/50000 (64%)]	Loss: 1.325412
#
# Validation set: Average loss: 1.5184, Accuracy: 4595/10000 (46%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.339509
# Train Epoch: 14 [32000/50000 (64%)]	Loss: 1.843347
#
# Validation set: Average loss: 1.5102, Accuracy: 4636/10000 (46%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 1.882060
# Train Epoch: 15 [32000/50000 (64%)]	Loss: 1.632209
#
# Validation set: Average loss: 1.5127, Accuracy: 4667/10000 (47%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 1.652993
# Train Epoch: 16 [32000/50000 (64%)]	Loss: 1.716275
#
# Validation set: Average loss: 1.5105, Accuracy: 4597/10000 (46%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 1.541201
# Train Epoch: 17 [32000/50000 (64%)]	Loss: 1.355713
#
# Validation set: Average loss: 1.5114, Accuracy: 4582/10000 (46%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 1.860647
# Train Epoch: 18 [32000/50000 (64%)]	Loss: 1.411050
#
# Validation set: Average loss: 1.5028, Accuracy: 4612/10000 (46%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 1.750591
# Train Epoch: 19 [32000/50000 (64%)]	Loss: 1.552627
#
# Validation set: Average loss: 1.5165, Accuracy: 4485/10000 (45%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 1.763417
# Train Epoch: 20 [32000/50000 (64%)]	Loss: 1.746138
#
# Validation set: Average loss: 1.5063, Accuracy: 4609/10000 (46%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 1.948007
# Train Epoch: 21 [32000/50000 (64%)]	Loss: 1.517836
#
# Validation set: Average loss: 1.4852, Accuracy: 4732/10000 (47%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 1.643826
# Train Epoch: 22 [32000/50000 (64%)]	Loss: 1.711944
#
# Validation set: Average loss: 1.4752, Accuracy: 4738/10000 (47%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 1.231030
# Train Epoch: 23 [32000/50000 (64%)]	Loss: 1.667483
#
# Validation set: Average loss: 1.4473, Accuracy: 4895/10000 (49%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 1.513902
# Train Epoch: 24 [32000/50000 (64%)]	Loss: 1.909659
#
# Validation set: Average loss: 1.4678, Accuracy: 4809/10000 (48%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 1.605819
# Train Epoch: 25 [32000/50000 (64%)]	Loss: 1.791492
#
# Validation set: Average loss: 1.4610, Accuracy: 4812/10000 (48%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 1.631400
# Train Epoch: 26 [32000/50000 (64%)]	Loss: 1.163201
#
# Validation set: Average loss: 1.4731, Accuracy: 4805/10000 (48%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 1.743903
# Train Epoch: 27 [32000/50000 (64%)]	Loss: 1.669570
#
# Validation set: Average loss: 1.4426, Accuracy: 4870/10000 (49%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 1.402982
# Train Epoch: 28 [32000/50000 (64%)]	Loss: 1.417022
#
# Validation set: Average loss: 1.4709, Accuracy: 4689/10000 (47%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 1.437520
# Train Epoch: 29 [32000/50000 (64%)]	Loss: 1.824101
#
# Validation set: Average loss: 1.4575, Accuracy: 4808/10000 (48%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 1.130444
# Train Epoch: 30 [32000/50000 (64%)]	Loss: 1.601377
#
# Validation set: Average loss: 1.5104, Accuracy: 4595/10000 (46%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 1.293852
# Train Epoch: 31 [32000/50000 (64%)]	Loss: 1.321377
#
# Validation set: Average loss: 1.4385, Accuracy: 4850/10000 (48%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 1.672168
# Train Epoch: 32 [32000/50000 (64%)]	Loss: 1.291512
#
# Validation set: Average loss: 1.4353, Accuracy: 4802/10000 (48%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 1.363899
# Train Epoch: 33 [32000/50000 (64%)]	Loss: 1.323395
#
# Validation set: Average loss: 1.4490, Accuracy: 4820/10000 (48%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 1.400951
# Train Epoch: 34 [32000/50000 (64%)]	Loss: 1.459161
#
# Validation set: Average loss: 1.4149, Accuracy: 4953/10000 (50%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 1.497389
# Train Epoch: 35 [32000/50000 (64%)]	Loss: 1.193564
#
# Validation set: Average loss: 1.4334, Accuracy: 4912/10000 (49%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 1.378126
# Train Epoch: 36 [32000/50000 (64%)]	Loss: 1.561104
#
# Validation set: Average loss: 1.4566, Accuracy: 4701/10000 (47%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 1.318125
# Train Epoch: 37 [32000/50000 (64%)]	Loss: 1.600201
#
# Validation set: Average loss: 1.4143, Accuracy: 4944/10000 (49%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 1.570453
# Train Epoch: 38 [32000/50000 (64%)]	Loss: 1.395838
#
# Validation set: Average loss: 1.4415, Accuracy: 4845/10000 (48%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 1.832777
# Train Epoch: 39 [32000/50000 (64%)]	Loss: 1.567635
#
# Validation set: Average loss: 1.4174, Accuracy: 4920/10000 (49%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 1.502038
# Train Epoch: 40 [32000/50000 (64%)]	Loss: 1.456570
#
# Validation set: Average loss: 1.4291, Accuracy: 4882/10000 (49%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 1.257143
# Train Epoch: 41 [32000/50000 (64%)]	Loss: 1.835091
#
# Validation set: Average loss: 1.4196, Accuracy: 4985/10000 (50%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 1.426696
# Train Epoch: 42 [32000/50000 (64%)]	Loss: 1.503513
#
# Validation set: Average loss: 1.4252, Accuracy: 4870/10000 (49%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 1.556080
# Train Epoch: 43 [32000/50000 (64%)]	Loss: 1.614435
#
# Validation set: Average loss: 1.4059, Accuracy: 4966/10000 (50%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 1.505473
# Train Epoch: 44 [32000/50000 (64%)]	Loss: 1.614442
#
# Validation set: Average loss: 1.4264, Accuracy: 4893/10000 (49%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 1.472800
# Train Epoch: 45 [32000/50000 (64%)]	Loss: 1.368729
#
# Validation set: Average loss: 1.4462, Accuracy: 4816/10000 (48%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 1.897172
# Train Epoch: 46 [32000/50000 (64%)]	Loss: 1.568274
#
# Validation set: Average loss: 1.4482, Accuracy: 4785/10000 (48%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 1.261430
# Train Epoch: 47 [32000/50000 (64%)]	Loss: 1.510609
#
# Validation set: Average loss: 1.4119, Accuracy: 4978/10000 (50%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 1.624716
# Train Epoch: 48 [32000/50000 (64%)]	Loss: 1.314790
#
# Validation set: Average loss: 1.4315, Accuracy: 4841/10000 (48%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 1.405015
# Train Epoch: 49 [32000/50000 (64%)]	Loss: 1.797124
#
# Validation set: Average loss: 1.4365, Accuracy: 4893/10000 (49%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 1.668184
# Train Epoch: 50 [32000/50000 (64%)]	Loss: 1.438892
#
# Validation set: Average loss: 1.4242, Accuracy: 4912/10000 (49%)
#
# Train Epoch: 51 [0/50000 (0%)]	Loss: 1.569510
# Train Epoch: 51 [32000/50000 (64%)]	Loss: 1.914021
#
# Validation set: Average loss: 1.4058, Accuracy: 4991/10000 (50%)
#
# Train Epoch: 52 [0/50000 (0%)]	Loss: 1.249015
# Train Epoch: 52 [32000/50000 (64%)]	Loss: 1.523173
#
# Validation set: Average loss: 1.4017, Accuracy: 4997/10000 (50%)
#
# Train Epoch: 53 [0/50000 (0%)]	Loss: 1.514089
# Train Epoch: 53 [32000/50000 (64%)]	Loss: 1.378156
#
# Validation set: Average loss: 1.4024, Accuracy: 4958/10000 (50%)
#
# Train Epoch: 54 [0/50000 (0%)]	Loss: 1.535886
# Train Epoch: 54 [32000/50000 (64%)]	Loss: 1.839937
#
# Validation set: Average loss: 1.3964, Accuracy: 5004/10000 (50%)
#
# Train Epoch: 55 [0/50000 (0%)]	Loss: 1.558615
# Train Epoch: 55 [32000/50000 (64%)]	Loss: 1.479549
#
# Validation set: Average loss: 1.4174, Accuracy: 4888/10000 (49%)
#
# Train Epoch: 56 [0/50000 (0%)]	Loss: 1.215749
# Train Epoch: 56 [32000/50000 (64%)]	Loss: 1.416075
#
# Validation set: Average loss: 1.4131, Accuracy: 4883/10000 (49%)
#
# Train Epoch: 57 [0/50000 (0%)]	Loss: 1.208586
# Train Epoch: 57 [32000/50000 (64%)]	Loss: 1.258080
#
# Validation set: Average loss: 1.4110, Accuracy: 4900/10000 (49%)
#
# Train Epoch: 58 [0/50000 (0%)]	Loss: 1.290772
# Train Epoch: 58 [32000/50000 (64%)]	Loss: 1.659197
#
# Validation set: Average loss: 1.4054, Accuracy: 4965/10000 (50%)
#
# Train Epoch: 59 [0/50000 (0%)]	Loss: 1.452433
# Train Epoch: 59 [32000/50000 (64%)]	Loss: 1.455572
#
# Validation set: Average loss: 1.4013, Accuracy: 4969/10000 (50%)
#
# Train Epoch: 60 [0/50000 (0%)]	Loss: 1.443802
# Train Epoch: 60 [32000/50000 (64%)]	Loss: 1.381180
#
# Validation set: Average loss: 1.3982, Accuracy: 4981/10000 (50%)
#
# Train Epoch: 61 [0/50000 (0%)]	Loss: 1.444585
# Train Epoch: 61 [32000/50000 (64%)]	Loss: 1.224505
#
# Validation set: Average loss: 1.3976, Accuracy: 4949/10000 (49%)
#
# Train Epoch: 62 [0/50000 (0%)]	Loss: 1.459780
# Train Epoch: 62 [32000/50000 (64%)]	Loss: 1.504522
#
# Validation set: Average loss: 1.4041, Accuracy: 4921/10000 (49%)
#
# Train Epoch: 63 [0/50000 (0%)]	Loss: 1.438339
# Train Epoch: 63 [32000/50000 (64%)]	Loss: 1.423925
#
# Validation set: Average loss: 1.4027, Accuracy: 5034/10000 (50%)
#
# Train Epoch: 64 [0/50000 (0%)]	Loss: 1.340609
# Train Epoch: 64 [32000/50000 (64%)]	Loss: 1.486617
#
# Validation set: Average loss: 1.4219, Accuracy: 4911/10000 (49%)
#
# Train Epoch: 65 [0/50000 (0%)]	Loss: 1.751129
# Train Epoch: 65 [32000/50000 (64%)]	Loss: 1.276292
#
# Validation set: Average loss: 1.3956, Accuracy: 5028/10000 (50%)
#
# Train Epoch: 66 [0/50000 (0%)]	Loss: 1.518656
# Train Epoch: 66 [32000/50000 (64%)]	Loss: 1.348873
#
# Validation set: Average loss: 1.3903, Accuracy: 5042/10000 (50%)
#
# Train Epoch: 67 [0/50000 (0%)]	Loss: 1.383854
# Train Epoch: 67 [32000/50000 (64%)]	Loss: 1.673988
#
# Validation set: Average loss: 1.3841, Accuracy: 5049/10000 (50%)
#
# Train Epoch: 68 [0/50000 (0%)]	Loss: 1.450516
# Train Epoch: 68 [32000/50000 (64%)]	Loss: 1.409867
#
# Validation set: Average loss: 1.4154, Accuracy: 4914/10000 (49%)
#
# Train Epoch: 69 [0/50000 (0%)]	Loss: 1.415816
# Train Epoch: 69 [32000/50000 (64%)]	Loss: 1.332619
#
# Validation set: Average loss: 1.3923, Accuracy: 5010/10000 (50%)
#
# Train Epoch: 70 [0/50000 (0%)]	Loss: 1.412791
# Train Epoch: 70 [32000/50000 (64%)]	Loss: 1.572510
#
# Validation set: Average loss: 1.3937, Accuracy: 5027/10000 (50%)
#
# Train Epoch: 71 [0/50000 (0%)]	Loss: 1.660620
# Train Epoch: 71 [32000/50000 (64%)]	Loss: 1.348131
#
# Validation set: Average loss: 1.3950, Accuracy: 5018/10000 (50%)
#
# Train Epoch: 72 [0/50000 (0%)]	Loss: 1.377123
# Train Epoch: 72 [32000/50000 (64%)]	Loss: 1.358766
#
# Validation set: Average loss: 1.3884, Accuracy: 4962/10000 (50%)
#
# Train Epoch: 73 [0/50000 (0%)]	Loss: 1.524211
# Train Epoch: 73 [32000/50000 (64%)]	Loss: 1.243187
#
# Validation set: Average loss: 1.4039, Accuracy: 5008/10000 (50%)
#
# Train Epoch: 74 [0/50000 (0%)]	Loss: 1.068314
# Train Epoch: 74 [32000/50000 (64%)]	Loss: 1.559991
#
# Validation set: Average loss: 1.4064, Accuracy: 4949/10000 (49%)
#
# Train Epoch: 75 [0/50000 (0%)]	Loss: 1.448216
# Train Epoch: 75 [32000/50000 (64%)]	Loss: 1.259867
#
# Validation set: Average loss: 1.4108, Accuracy: 4977/10000 (50%)
#
# Train Epoch: 76 [0/50000 (0%)]	Loss: 1.224429
# Train Epoch: 76 [32000/50000 (64%)]	Loss: 1.526024
#
# Validation set: Average loss: 1.3975, Accuracy: 5026/10000 (50%)
#
# Train Epoch: 77 [0/50000 (0%)]	Loss: 1.267911
# Train Epoch: 77 [32000/50000 (64%)]	Loss: 1.223199
#
# Validation set: Average loss: 1.3851, Accuracy: 5018/10000 (50%)
#
# Train Epoch: 78 [0/50000 (0%)]	Loss: 1.340241
# Train Epoch: 78 [32000/50000 (64%)]	Loss: 1.452605
#
# Validation set: Average loss: 1.3880, Accuracy: 5013/10000 (50%)
#
# Train Epoch: 79 [0/50000 (0%)]	Loss: 1.302129
# Train Epoch: 79 [32000/50000 (64%)]	Loss: 1.497950
#
# Validation set: Average loss: 1.3813, Accuracy: 5054/10000 (51%)
#
# Train Epoch: 80 [0/50000 (0%)]	Loss: 1.428945
# Train Epoch: 80 [32000/50000 (64%)]	Loss: 1.476936
#
# Validation set: Average loss: 1.3883, Accuracy: 4994/10000 (50%)
#
# Train Epoch: 81 [0/50000 (0%)]	Loss: 1.785988
# Train Epoch: 81 [32000/50000 (64%)]	Loss: 1.615873
#
# Validation set: Average loss: 1.4005, Accuracy: 4984/10000 (50%)
#
# Train Epoch: 82 [0/50000 (0%)]	Loss: 1.449229
# Train Epoch: 82 [32000/50000 (64%)]	Loss: 1.542044
#
# Validation set: Average loss: 1.3928, Accuracy: 4982/10000 (50%)
#
# Train Epoch: 83 [0/50000 (0%)]	Loss: 1.383449
# Train Epoch: 83 [32000/50000 (64%)]	Loss: 1.366787
#
# Validation set: Average loss: 1.3832, Accuracy: 5085/10000 (51%)
#
# Train Epoch: 84 [0/50000 (0%)]	Loss: 1.019821
# Train Epoch: 84 [32000/50000 (64%)]	Loss: 1.436343
#
# Validation set: Average loss: 1.4167, Accuracy: 4889/10000 (49%)
#
# Train Epoch: 85 [0/50000 (0%)]	Loss: 1.103156
# Train Epoch: 85 [32000/50000 (64%)]	Loss: 1.497527
#
# Validation set: Average loss: 1.3904, Accuracy: 5045/10000 (50%)
#
# Train Epoch: 86 [0/50000 (0%)]	Loss: 1.606409
# Train Epoch: 86 [32000/50000 (64%)]	Loss: 1.395607
#
# Validation set: Average loss: 1.3891, Accuracy: 5042/10000 (50%)
#
# Train Epoch: 87 [0/50000 (0%)]	Loss: 1.397069
# Train Epoch: 87 [32000/50000 (64%)]	Loss: 1.308048
#
# Validation set: Average loss: 1.4050, Accuracy: 4944/10000 (49%)
#
# Train Epoch: 88 [0/50000 (0%)]	Loss: 1.154428
# Train Epoch: 88 [32000/50000 (64%)]	Loss: 1.039256
#
# Validation set: Average loss: 1.3870, Accuracy: 5042/10000 (50%)
#
# Train Epoch: 89 [0/50000 (0%)]	Loss: 1.563855
# Train Epoch: 89 [32000/50000 (64%)]	Loss: 1.141785
#
# Validation set: Average loss: 1.3895, Accuracy: 5014/10000 (50%)
#
# Train Epoch: 90 [0/50000 (0%)]	Loss: 1.558840
# Train Epoch: 90 [32000/50000 (64%)]	Loss: 1.291125
#
# Validation set: Average loss: 1.3741, Accuracy: 5059/10000 (51%)
#
# Train Epoch: 91 [0/50000 (0%)]	Loss: 1.440228
# Train Epoch: 91 [32000/50000 (64%)]	Loss: 1.551615
#
# Validation set: Average loss: 1.3796, Accuracy: 5049/10000 (50%)
#
# Train Epoch: 92 [0/50000 (0%)]	Loss: 1.117658
# Train Epoch: 92 [32000/50000 (64%)]	Loss: 1.450727
#
# Validation set: Average loss: 1.4009, Accuracy: 5001/10000 (50%)
#
# Train Epoch: 93 [0/50000 (0%)]	Loss: 1.324213
# Train Epoch: 93 [32000/50000 (64%)]	Loss: 1.323313
#
# Validation set: Average loss: 1.3950, Accuracy: 5004/10000 (50%)
#
# Train Epoch: 94 [0/50000 (0%)]	Loss: 1.424148
# Train Epoch: 94 [32000/50000 (64%)]	Loss: 1.282378
#
# Validation set: Average loss: 1.3827, Accuracy: 5000/10000 (50%)
#
# Train Epoch: 95 [0/50000 (0%)]	Loss: 1.582172
# Train Epoch: 95 [32000/50000 (64%)]	Loss: 1.141313
#
# Validation set: Average loss: 1.3714, Accuracy: 5100/10000 (51%)
#
# Train Epoch: 96 [0/50000 (0%)]	Loss: 1.363769
# Train Epoch: 96 [32000/50000 (64%)]	Loss: 1.452539
#
# Validation set: Average loss: 1.3770, Accuracy: 5056/10000 (51%)
#
# Train Epoch: 97 [0/50000 (0%)]	Loss: 0.995072
# Train Epoch: 97 [32000/50000 (64%)]	Loss: 1.225542
#
# Validation set: Average loss: 1.3779, Accuracy: 5070/10000 (51%)
#
# Train Epoch: 98 [0/50000 (0%)]	Loss: 0.950246
# Train Epoch: 98 [32000/50000 (64%)]	Loss: 1.447578
#
# Validation set: Average loss: 1.3853, Accuracy: 5069/10000 (51%)
#
# Train Epoch: 99 [0/50000 (0%)]	Loss: 1.161541
# Train Epoch: 99 [32000/50000 (64%)]	Loss: 1.551971
#
# Validation set: Average loss: 1.3763, Accuracy: 5053/10000 (51%)
#
# Train Epoch: 100 [0/50000 (0%)]	Loss: 1.586873
# Train Epoch: 100 [32000/50000 (64%)]	Loss: 1.174515
#
# Validation set: Average loss: 1.3805, Accuracy: 5082/10000 (51%)
#
# CPU times: user 17min 28s, sys: 2min 43s, total: 20min 12s
# Wall time: 18min 9s

# %% [markdown]
# ## Profiling the model

# %%
from thop import profile

input = torch.randn(3, 32, 32).to(device)
flops, params = profile(Net().to(device), inputs=(input, ))
print('Params(M): %.2f, FLOPs(M): %.2f' % (params / (1000 ** 2), flops / (1000 ** 2)))
# Out:
# Register FLOP counter for module Linear(in_features=3072, out_features=49, bias=True)
# Register FLOP counter for module Dropout(p=0.2, inplace=False)
# Register FLOP counter for module Linear(in_features=49, out_features=56, bias=True)
# Register FLOP counter for module Dropout(p=0.2, inplace=False)
# Register FLOP counter for module Linear(in_features=56, out_features=10, bias=True)
# Params(M): 0.15, FLOPs(M): 0.31
