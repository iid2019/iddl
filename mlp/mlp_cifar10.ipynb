# %%
# For inline plotting
# %matplotlib inline

# For auto reloading
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # CIFAR10 dataset with MLP
#
# [reference](https://github.com/CSCfi/machine-learning-scripts/blob/master/notebooks/pytorch-mnist-mlp.ipynb)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms

import numpy as np
import matplotlib.pyplot as plt

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print('Using PyTorch version:', torch.__version__, ' Device:', device)
# Out:
# Using PyTorch version: 1.3.1  Device: cuda

# %% [markdown]
# ## Data
#
# Next we'll load the CIFAR10 data. First time we may have to download the data, which can take a while.
#
# Note that we are here using the CIFAR10 test data for *validation*, instead of for testing the final model.

# %%
batch_size = 32

train_dataset = datasets.CIFAR10('./data', 
                               train=True, 
                               download=True, 
                               transform=transforms.ToTensor())

validation_dataset = datasets.CIFAR10('./data', 
                                    train=False, 
                                    transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, 
                                                batch_size=batch_size, 
                                                shuffle=False)
# Out:
# Files already downloaded and verified

# %% [markdown]
# The train and test data are provided via data loaders that provide iterators over the datasets. The first element of training data (`X_train`) is a 4th-order tensor of size (`batch_size`, 3, 32, 32), i.e. it consists of a batch of images of size $3 \times 32 \times 32$ pixels. `y_train` is a vector containing the correct classes ("0", "1", ..., "9") for each training digit.

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 3, 32, 32]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %% [markdown]
# Here are the first 10 training digits:

# %% [markdown]
# ## MLP network definition
#
# Let's define the network as a Python class.  We have to write the `__init__()` and `forward()` methods, and PyTorch will automatically generate a `backward()` method for computing the gradients for the backward pass.
#
# Finally, we define an optimizer to update the model parameters based on the computed gradients.  We select *stochastic gradient descent (with momentum)* as the optimization algorithm, and set *learning rate* to 0.01.  Note that there are [several different options](http://pytorch.org/docs/optim.html#algorithms) for the optimizer in PyTorch that we could use instead of *SGD*.

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3*32*32, 50)
        self.fc1_drop = nn.Dropout(0.2)
        self.fc2 = nn.Linear(50, 50)
        self.fc2_drop = nn.Dropout(0.2)
        self.fc3 = nn.Linear(50, 10)

    def forward(self, x):
        x = x.view(-1, 3*32*32)
        x = F.relu(self.fc1(x))
        x = self.fc1_drop(x)
        x = F.relu(self.fc2(x))
        x = self.fc2_drop(x)
        return F.log_softmax(self.fc3(x), dim=1)

model = Net().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=3072, out_features=50, bias=True)
#   (fc1_drop): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=50, out_features=50, bias=True)
#   (fc2_drop): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=50, out_features=10, bias=True)
# )

# %% [markdown]
# ## Learning
#
# Let's now define functions to `train()` and `validate()` the model.

# %%
def train(epoch, log_interval=200):
    # Set model to training mode
    model.train()
    
    # Loop over each batch from the training set
    for batch_idx, (data, target) in enumerate(train_loader):
        # Copy data to GPU if needed
        data = data.to(device)
        target = target.to(device)

        # Zero gradient buffers
        optimizer.zero_grad() 
        
        # Pass data through the network
        output = model(data)

        # Calculate loss
        loss = criterion(output, target)

        # Backpropagate
        loss.backward()
        
        # Update weights
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

# %%
def validate(loss_vector, accuracy_vector):
    model.eval()
    val_loss, correct = 0, 0
    for data, target in validation_loader:
        data = data.to(device)
        target = target.to(device)
        output = model(data)
        val_loss += criterion(output, target).data.item()
        pred = output.data.max(1)[1] # get the index of the max log-probability
        correct += pred.eq(target.data).cpu().sum()

    val_loss /= len(validation_loader)
    loss_vector.append(val_loss)

    accuracy = 100. * correct.to(torch.float32) / len(validation_loader.dataset)
    accuracy_vector.append(accuracy)
    
    print('\nValidation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        val_loss, correct, len(validation_loader.dataset), accuracy))

# %% [markdown]
# Now we are ready to train our model using the `train()` function.  An *epoch* means one pass through the whole training data. After each epoch, we evaluate the model using `validate()`.

# %%
# %%time
epochs = 100

lossv, accv = [], []
for epoch in range(1, epochs + 1):
    train(epoch, log_interval=1000)
    validate(lossv, accv)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.311072
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 2.082558
#
# Validation set: Average loss: 1.8381, Accuracy: 3438/10000 (34%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 2.037895
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 1.953444
#
# Validation set: Average loss: 1.7622, Accuracy: 3742/10000 (37%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.598591
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 1.794115
#
# Validation set: Average loss: 1.6704, Accuracy: 4058/10000 (41%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.795227
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 1.862281
#
# Validation set: Average loss: 1.6471, Accuracy: 4179/10000 (42%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.814846
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 1.696871
#
# Validation set: Average loss: 1.6134, Accuracy: 4229/10000 (42%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.866219
# Train Epoch: 6 [32000/50000 (64%)]	Loss: 1.907664
#
# Validation set: Average loss: 1.6316, Accuracy: 4151/10000 (42%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.696241
# Train Epoch: 7 [32000/50000 (64%)]	Loss: 1.559474
#
# Validation set: Average loss: 1.5991, Accuracy: 4415/10000 (44%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.876380
# Train Epoch: 8 [32000/50000 (64%)]	Loss: 1.642015
#
# Validation set: Average loss: 1.5573, Accuracy: 4496/10000 (45%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.796284
# Train Epoch: 9 [32000/50000 (64%)]	Loss: 1.887107
#
# Validation set: Average loss: 1.5922, Accuracy: 4374/10000 (44%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.740181
# Train Epoch: 10 [32000/50000 (64%)]	Loss: 1.559176
#
# Validation set: Average loss: 1.5382, Accuracy: 4562/10000 (46%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.453720
# Train Epoch: 11 [32000/50000 (64%)]	Loss: 1.529119
#
# Validation set: Average loss: 1.5412, Accuracy: 4509/10000 (45%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.544956
# Train Epoch: 12 [32000/50000 (64%)]	Loss: 1.691029
#
# Validation set: Average loss: 1.5703, Accuracy: 4453/10000 (45%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 1.967764
# Train Epoch: 13 [32000/50000 (64%)]	Loss: 1.485952
#
# Validation set: Average loss: 1.5402, Accuracy: 4583/10000 (46%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.629192
# Train Epoch: 14 [32000/50000 (64%)]	Loss: 1.678414
#
# Validation set: Average loss: 1.5064, Accuracy: 4629/10000 (46%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 1.514394
# Train Epoch: 15 [32000/50000 (64%)]	Loss: 1.431151
#
# Validation set: Average loss: 1.5231, Accuracy: 4473/10000 (45%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 1.362422
# Train Epoch: 16 [32000/50000 (64%)]	Loss: 1.709235
#
# Validation set: Average loss: 1.5026, Accuracy: 4657/10000 (47%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 1.250898
# Train Epoch: 17 [32000/50000 (64%)]	Loss: 1.438044
#
# Validation set: Average loss: 1.4940, Accuracy: 4677/10000 (47%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 1.660203
# Train Epoch: 18 [32000/50000 (64%)]	Loss: 1.521124
#
# Validation set: Average loss: 1.4714, Accuracy: 4765/10000 (48%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 1.556126
# Train Epoch: 19 [32000/50000 (64%)]	Loss: 1.687883
#
# Validation set: Average loss: 1.4698, Accuracy: 4767/10000 (48%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 1.938077
# Train Epoch: 20 [32000/50000 (64%)]	Loss: 1.666493
#
# Validation set: Average loss: 1.4734, Accuracy: 4763/10000 (48%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 1.659098
# Train Epoch: 21 [32000/50000 (64%)]	Loss: 1.788210
#
# Validation set: Average loss: 1.4690, Accuracy: 4747/10000 (47%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 1.235206
# Train Epoch: 22 [32000/50000 (64%)]	Loss: 1.596032
#
# Validation set: Average loss: 1.4729, Accuracy: 4695/10000 (47%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 1.994362
# Train Epoch: 23 [32000/50000 (64%)]	Loss: 1.534678
#
# Validation set: Average loss: 1.4596, Accuracy: 4734/10000 (47%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 1.551035
# Train Epoch: 24 [32000/50000 (64%)]	Loss: 1.443551
#
# Validation set: Average loss: 1.4559, Accuracy: 4749/10000 (47%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 1.427483
# Train Epoch: 25 [32000/50000 (64%)]	Loss: 1.427989
#
# Validation set: Average loss: 1.4742, Accuracy: 4737/10000 (47%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 1.432882
# Train Epoch: 26 [32000/50000 (64%)]	Loss: 1.530328
#
# Validation set: Average loss: 1.4493, Accuracy: 4763/10000 (48%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 1.393861
# Train Epoch: 27 [32000/50000 (64%)]	Loss: 1.429265
#
# Validation set: Average loss: 1.4335, Accuracy: 4849/10000 (48%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 1.415404
# Train Epoch: 28 [32000/50000 (64%)]	Loss: 1.378713
#
# Validation set: Average loss: 1.4468, Accuracy: 4836/10000 (48%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 1.723415
# Train Epoch: 29 [32000/50000 (64%)]	Loss: 1.557364
#
# Validation set: Average loss: 1.4499, Accuracy: 4798/10000 (48%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 1.431320
# Train Epoch: 30 [32000/50000 (64%)]	Loss: 1.493135
#
# Validation set: Average loss: 1.4445, Accuracy: 4876/10000 (49%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 1.421605
# Train Epoch: 31 [32000/50000 (64%)]	Loss: 1.266286
#
# Validation set: Average loss: 1.4539, Accuracy: 4805/10000 (48%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 1.583835
# Train Epoch: 32 [32000/50000 (64%)]	Loss: 1.240088
#
# Validation set: Average loss: 1.4329, Accuracy: 4894/10000 (49%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 1.560134
# Train Epoch: 33 [32000/50000 (64%)]	Loss: 1.532953
#
# Validation set: Average loss: 1.4374, Accuracy: 4864/10000 (49%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 1.365212
# Train Epoch: 34 [32000/50000 (64%)]	Loss: 1.645606
#
# Validation set: Average loss: 1.4356, Accuracy: 4851/10000 (49%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 1.518493
# Train Epoch: 35 [32000/50000 (64%)]	Loss: 1.512440
#
# Validation set: Average loss: 1.4256, Accuracy: 4929/10000 (49%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 1.307279
# Train Epoch: 36 [32000/50000 (64%)]	Loss: 1.456435
#
# Validation set: Average loss: 1.4187, Accuracy: 4902/10000 (49%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 1.595029
# Train Epoch: 37 [32000/50000 (64%)]	Loss: 1.135246
#
# Validation set: Average loss: 1.4129, Accuracy: 4932/10000 (49%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 1.473833
# Train Epoch: 38 [32000/50000 (64%)]	Loss: 1.357667
#
# Validation set: Average loss: 1.4096, Accuracy: 5003/10000 (50%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 1.410122
# Train Epoch: 39 [32000/50000 (64%)]	Loss: 1.084552
#
# Validation set: Average loss: 1.4078, Accuracy: 4987/10000 (50%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 1.356817
# Train Epoch: 40 [32000/50000 (64%)]	Loss: 1.161947
#
# Validation set: Average loss: 1.4352, Accuracy: 4860/10000 (49%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 1.273812
# Train Epoch: 41 [32000/50000 (64%)]	Loss: 1.448260
#
# Validation set: Average loss: 1.4161, Accuracy: 4959/10000 (50%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 1.414122
# Train Epoch: 42 [32000/50000 (64%)]	Loss: 1.209396
#
# Validation set: Average loss: 1.4267, Accuracy: 4846/10000 (48%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 1.824854
# Train Epoch: 43 [32000/50000 (64%)]	Loss: 1.713899
#
# Validation set: Average loss: 1.4277, Accuracy: 4885/10000 (49%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 1.577665
# Train Epoch: 44 [32000/50000 (64%)]	Loss: 1.838725
#
# Validation set: Average loss: 1.4049, Accuracy: 5048/10000 (50%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 1.184749
# Train Epoch: 45 [32000/50000 (64%)]	Loss: 1.006468
#
# Validation set: Average loss: 1.4360, Accuracy: 4884/10000 (49%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 1.248549
# Train Epoch: 46 [32000/50000 (64%)]	Loss: 1.370616
#
# Validation set: Average loss: 1.4050, Accuracy: 5000/10000 (50%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 1.307557
# Train Epoch: 47 [32000/50000 (64%)]	Loss: 1.218604
#
# Validation set: Average loss: 1.4133, Accuracy: 4923/10000 (49%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 1.255061
# Train Epoch: 48 [32000/50000 (64%)]	Loss: 1.312244
#
# Validation set: Average loss: 1.4128, Accuracy: 4898/10000 (49%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 1.359631
# Train Epoch: 49 [32000/50000 (64%)]	Loss: 1.206342
#
# Validation set: Average loss: 1.4179, Accuracy: 4940/10000 (49%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 1.661076
# Train Epoch: 50 [32000/50000 (64%)]	Loss: 1.575362
#
# Validation set: Average loss: 1.3978, Accuracy: 5013/10000 (50%)
#
# Train Epoch: 51 [0/50000 (0%)]	Loss: 1.401747
# Train Epoch: 51 [32000/50000 (64%)]	Loss: 1.553538
#
# Validation set: Average loss: 1.4053, Accuracy: 5027/10000 (50%)
#
# Train Epoch: 52 [0/50000 (0%)]	Loss: 1.087206
# Train Epoch: 52 [32000/50000 (64%)]	Loss: 1.264165
#
# Validation set: Average loss: 1.4114, Accuracy: 4959/10000 (50%)
#
# Train Epoch: 53 [0/50000 (0%)]	Loss: 1.513940
# Train Epoch: 53 [32000/50000 (64%)]	Loss: 1.399835
#
# Validation set: Average loss: 1.4032, Accuracy: 4962/10000 (50%)
#
# Train Epoch: 54 [0/50000 (0%)]	Loss: 1.512196
# Train Epoch: 54 [32000/50000 (64%)]	Loss: 1.560315
#
# Validation set: Average loss: 1.3996, Accuracy: 5038/10000 (50%)
#
# Train Epoch: 55 [0/50000 (0%)]	Loss: 1.271143
# Train Epoch: 55 [32000/50000 (64%)]	Loss: 1.395777
#
# Validation set: Average loss: 1.3932, Accuracy: 4989/10000 (50%)
#
# Train Epoch: 56 [0/50000 (0%)]	Loss: 1.808441
# Train Epoch: 56 [32000/50000 (64%)]	Loss: 1.429213
#
# Validation set: Average loss: 1.4090, Accuracy: 4952/10000 (50%)
#
# Train Epoch: 57 [0/50000 (0%)]	Loss: 1.106304
# Train Epoch: 57 [32000/50000 (64%)]	Loss: 1.311731
#
# Validation set: Average loss: 1.4005, Accuracy: 4986/10000 (50%)
#
# Train Epoch: 58 [0/50000 (0%)]	Loss: 1.423750
# Train Epoch: 58 [32000/50000 (64%)]	Loss: 1.364025
#
# Validation set: Average loss: 1.3905, Accuracy: 5040/10000 (50%)
#
# Train Epoch: 59 [0/50000 (0%)]	Loss: 1.375918
# Train Epoch: 59 [32000/50000 (64%)]	Loss: 1.320824
#
# Validation set: Average loss: 1.3960, Accuracy: 5047/10000 (50%)
#
# Train Epoch: 60 [0/50000 (0%)]	Loss: 1.497872
# Train Epoch: 60 [32000/50000 (64%)]	Loss: 1.550557
#
# Validation set: Average loss: 1.4303, Accuracy: 4803/10000 (48%)
#
# Train Epoch: 61 [0/50000 (0%)]	Loss: 1.587573
# Train Epoch: 61 [32000/50000 (64%)]	Loss: 1.441014
#
# Validation set: Average loss: 1.3869, Accuracy: 5037/10000 (50%)
#
# Train Epoch: 62 [0/50000 (0%)]	Loss: 1.203343
# Train Epoch: 62 [32000/50000 (64%)]	Loss: 1.305348
#
# Validation set: Average loss: 1.4007, Accuracy: 4998/10000 (50%)
#
# Train Epoch: 63 [0/50000 (0%)]	Loss: 1.229572
# Train Epoch: 63 [32000/50000 (64%)]	Loss: 1.036335
#
# Validation set: Average loss: 1.4012, Accuracy: 4986/10000 (50%)
#
# Train Epoch: 64 [0/50000 (0%)]	Loss: 1.296671
# Train Epoch: 64 [32000/50000 (64%)]	Loss: 1.511954
#
# Validation set: Average loss: 1.4299, Accuracy: 4880/10000 (49%)
#
# Train Epoch: 65 [0/50000 (0%)]	Loss: 1.426485
# Train Epoch: 65 [32000/50000 (64%)]	Loss: 1.672612
#
# Validation set: Average loss: 1.3973, Accuracy: 5012/10000 (50%)
#
# Train Epoch: 66 [0/50000 (0%)]	Loss: 1.314861
# Train Epoch: 66 [32000/50000 (64%)]	Loss: 1.358012
#
# Validation set: Average loss: 1.3907, Accuracy: 5081/10000 (51%)
#
# Train Epoch: 67 [0/50000 (0%)]	Loss: 1.460654
# Train Epoch: 67 [32000/50000 (64%)]	Loss: 1.317684
#
# Validation set: Average loss: 1.3880, Accuracy: 5051/10000 (51%)
#
# Train Epoch: 68 [0/50000 (0%)]	Loss: 1.443131
# Train Epoch: 68 [32000/50000 (64%)]	Loss: 1.427133
#
# Validation set: Average loss: 1.3946, Accuracy: 4991/10000 (50%)
#
# Train Epoch: 69 [0/50000 (0%)]	Loss: 1.481806
# Train Epoch: 69 [32000/50000 (64%)]	Loss: 1.449061
#
# Validation set: Average loss: 1.3745, Accuracy: 5087/10000 (51%)
#
# Train Epoch: 70 [0/50000 (0%)]	Loss: 1.558178
# Train Epoch: 70 [32000/50000 (64%)]	Loss: 1.256141
#
# Validation set: Average loss: 1.3954, Accuracy: 5062/10000 (51%)
#
# Train Epoch: 71 [0/50000 (0%)]	Loss: 1.343256
# Train Epoch: 71 [32000/50000 (64%)]	Loss: 1.368877
#
# Validation set: Average loss: 1.4053, Accuracy: 5036/10000 (50%)
#
# Train Epoch: 72 [0/50000 (0%)]	Loss: 1.206374
# Train Epoch: 72 [32000/50000 (64%)]	Loss: 1.538490
#
# Validation set: Average loss: 1.3865, Accuracy: 5057/10000 (51%)
#
# Train Epoch: 73 [0/50000 (0%)]	Loss: 1.094664
# Train Epoch: 73 [32000/50000 (64%)]	Loss: 1.393534
#
# Validation set: Average loss: 1.3942, Accuracy: 5068/10000 (51%)
#
# Train Epoch: 74 [0/50000 (0%)]	Loss: 0.931547
# Train Epoch: 74 [32000/50000 (64%)]	Loss: 1.029737
#
# Validation set: Average loss: 1.3841, Accuracy: 5066/10000 (51%)
#
# Train Epoch: 75 [0/50000 (0%)]	Loss: 1.340819
# Train Epoch: 75 [32000/50000 (64%)]	Loss: 1.281518
#
# Validation set: Average loss: 1.3853, Accuracy: 5028/10000 (50%)
#
# Train Epoch: 76 [0/50000 (0%)]	Loss: 1.480776
# Train Epoch: 76 [32000/50000 (64%)]	Loss: 1.318142
#
# Validation set: Average loss: 1.3892, Accuracy: 5029/10000 (50%)
#
# Train Epoch: 77 [0/50000 (0%)]	Loss: 1.564494
# Train Epoch: 77 [32000/50000 (64%)]	Loss: 1.256420
#
# Validation set: Average loss: 1.3785, Accuracy: 5022/10000 (50%)
#
# Train Epoch: 78 [0/50000 (0%)]	Loss: 1.308651
# Train Epoch: 78 [32000/50000 (64%)]	Loss: 1.762247
#
# Validation set: Average loss: 1.3899, Accuracy: 5007/10000 (50%)
#
# Train Epoch: 79 [0/50000 (0%)]	Loss: 1.495555
# Train Epoch: 79 [32000/50000 (64%)]	Loss: 1.429865
#
# Validation set: Average loss: 1.3930, Accuracy: 5043/10000 (50%)
#
# Train Epoch: 80 [0/50000 (0%)]	Loss: 1.266491
# Train Epoch: 80 [32000/50000 (64%)]	Loss: 1.394325
#
# Validation set: Average loss: 1.3940, Accuracy: 5037/10000 (50%)
#
# Train Epoch: 81 [0/50000 (0%)]	Loss: 1.122895
# Train Epoch: 81 [32000/50000 (64%)]	Loss: 1.114519
#
# Validation set: Average loss: 1.3749, Accuracy: 5120/10000 (51%)
#
# Train Epoch: 82 [0/50000 (0%)]	Loss: 1.381222
# Train Epoch: 82 [32000/50000 (64%)]	Loss: 1.239591
#
# Validation set: Average loss: 1.3847, Accuracy: 5063/10000 (51%)
#
# Train Epoch: 83 [0/50000 (0%)]	Loss: 1.485112
# Train Epoch: 83 [32000/50000 (64%)]	Loss: 1.588980
#
# Validation set: Average loss: 1.3825, Accuracy: 5038/10000 (50%)
#
# Train Epoch: 84 [0/50000 (0%)]	Loss: 1.687728
# Train Epoch: 84 [32000/50000 (64%)]	Loss: 1.318982
#
# Validation set: Average loss: 1.3916, Accuracy: 5060/10000 (51%)
#
# Train Epoch: 85 [0/50000 (0%)]	Loss: 1.161852
# Train Epoch: 85 [32000/50000 (64%)]	Loss: 1.280012
#
# Validation set: Average loss: 1.4010, Accuracy: 4980/10000 (50%)
#
# Train Epoch: 86 [0/50000 (0%)]	Loss: 1.555376
# Train Epoch: 86 [32000/50000 (64%)]	Loss: 1.398772
#
# Validation set: Average loss: 1.3825, Accuracy: 5041/10000 (50%)
#
# Train Epoch: 87 [0/50000 (0%)]	Loss: 1.511300
# Train Epoch: 87 [32000/50000 (64%)]	Loss: 1.356331
#
# Validation set: Average loss: 1.3834, Accuracy: 5091/10000 (51%)
#
# Train Epoch: 88 [0/50000 (0%)]	Loss: 1.411101
# Train Epoch: 88 [32000/50000 (64%)]	Loss: 1.253111
#
# Validation set: Average loss: 1.3710, Accuracy: 5112/10000 (51%)
#
# Train Epoch: 89 [0/50000 (0%)]	Loss: 1.451888
# Train Epoch: 89 [32000/50000 (64%)]	Loss: 1.433416
#
# Validation set: Average loss: 1.4046, Accuracy: 5036/10000 (50%)
#
# Train Epoch: 90 [0/50000 (0%)]	Loss: 1.536638
# Train Epoch: 90 [32000/50000 (64%)]	Loss: 1.451147
#
# Validation set: Average loss: 1.3821, Accuracy: 4977/10000 (50%)
#
# Train Epoch: 91 [0/50000 (0%)]	Loss: 1.653655
# Train Epoch: 91 [32000/50000 (64%)]	Loss: 1.154965
#
# Validation set: Average loss: 1.3892, Accuracy: 5077/10000 (51%)
#
# Train Epoch: 92 [0/50000 (0%)]	Loss: 1.569272
# Train Epoch: 92 [32000/50000 (64%)]	Loss: 1.390847
#
# Validation set: Average loss: 1.3887, Accuracy: 5055/10000 (51%)
#
# Train Epoch: 93 [0/50000 (0%)]	Loss: 1.337616
# Train Epoch: 93 [32000/50000 (64%)]	Loss: 1.461414
#
# Validation set: Average loss: 1.3822, Accuracy: 5070/10000 (51%)
#
# Train Epoch: 94 [0/50000 (0%)]	Loss: 1.646637
# Train Epoch: 94 [32000/50000 (64%)]	Loss: 1.468514
#
# Validation set: Average loss: 1.3810, Accuracy: 5069/10000 (51%)
#
# Train Epoch: 95 [0/50000 (0%)]	Loss: 1.421100
# Train Epoch: 95 [32000/50000 (64%)]	Loss: 1.265421
#
# Validation set: Average loss: 1.3907, Accuracy: 5027/10000 (50%)
#
# Train Epoch: 96 [0/50000 (0%)]	Loss: 1.660163
# Train Epoch: 96 [32000/50000 (64%)]	Loss: 1.339514
#
# Validation set: Average loss: 1.3878, Accuracy: 5058/10000 (51%)
#
# Train Epoch: 97 [0/50000 (0%)]	Loss: 1.367322
# Train Epoch: 97 [32000/50000 (64%)]	Loss: 1.228052
#
# Validation set: Average loss: 1.3794, Accuracy: 5071/10000 (51%)
#
# Train Epoch: 98 [0/50000 (0%)]	Loss: 1.435767
# Train Epoch: 98 [32000/50000 (64%)]	Loss: 1.461576
#
# Validation set: Average loss: 1.3778, Accuracy: 5004/10000 (50%)
#
# Train Epoch: 99 [0/50000 (0%)]	Loss: 1.432902
# Train Epoch: 99 [32000/50000 (64%)]	Loss: 1.338663
#
# Validation set: Average loss: 1.3669, Accuracy: 5161/10000 (52%)
#
# Train Epoch: 100 [0/50000 (0%)]	Loss: 1.113828
# Train Epoch: 100 [32000/50000 (64%)]	Loss: 1.447542
#
# Validation set: Average loss: 1.3770, Accuracy: 5073/10000 (51%)
#
# CPU times: user 18min 49s, sys: 4min 36s, total: 23min 25s
# Wall time: 22min 40s
