# %%
# For inline plotting
# %matplotlib inline

# For auto reloading
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # CIFAR10 dataset with MLP
#
# [reference](https://github.com/CSCfi/machine-learning-scripts/blob/master/notebooks/pytorch-mnist-mlp.ipynb)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms

import numpy as np
import matplotlib.pyplot as plt

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print('Using PyTorch version:', torch.__version__, ' Device:', device)
# Out:
# Using PyTorch version: 1.3.1  Device: cuda

# %% [markdown]
# ## Data
#
# Next we'll load the CIFAR10 data. First time we may have to download the data, which can take a while.
#
# Note that we are here using the CIFAR10 test data for *validation*, instead of for testing the final model.

# %%
batch_size = 32

train_dataset = datasets.CIFAR10('./data', 
                               train=True, 
                               download=True, 
                               transform=transforms.ToTensor())

validation_dataset = datasets.CIFAR10('./data', 
                                    train=False, 
                                    transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, 
                                                batch_size=batch_size, 
                                                shuffle=False)
# Out:
# Files already downloaded and verified

# %% [markdown]
# The train and test data are provided via data loaders that provide iterators over the datasets. The first element of training data (`X_train`) is a 4th-order tensor of size (`batch_size`, 3, 32, 32), i.e. it consists of a batch of images of size $3 \times 32 \times 32$ pixels. `y_train` is a vector containing the correct classes ("0", "1", ..., "9") for each training digit.

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 3, 32, 32]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %% [markdown]
# Here are the first 10 training digits:

# %% [markdown]
# ## MLP network definition
#
# Let's define the network as a Python class.  We have to write the `__init__()` and `forward()` methods, and PyTorch will automatically generate a `backward()` method for computing the gradients for the backward pass.
#
# Finally, we define an optimizer to update the model parameters based on the computed gradients.  We select *stochastic gradient descent (with momentum)* as the optimization algorithm, and set *learning rate* to 0.01.  Note that there are [several different options](http://pytorch.org/docs/optim.html#algorithms) for the optimizer in PyTorch that we could use instead of *SGD*.

# %%
import sys
sys.path.append('../bibd')
from bibd_layer import BibdLinear

r = 7

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.fc1 = nn.Linear(3*32*32, r*(r+1))
        self.fc1_drop = nn.Dropout(0.2)
        self.bibd2 = BibdLinear(r*(r+1), r*r, number_of_block=r)
        self.fc3 = nn.Linear(r*r, 10)

    def forward(self, x):
        x = x.view(-1, 3*32*32)
        x = F.relu(self.fc1(x))
        x = self.fc1_drop(x)
        x = F.relu(self.bibd2(x))
        return F.log_softmax(self.fc3(x), dim=1)

model = Net().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=3072, out_features=56, bias=True)
#   (fc1_drop): Dropout(p=0.2, inplace=False)
#   (bibd2): BibdLinear()
#   (fc3): Linear(in_features=49, out_features=10, bias=True)
# )

# %% [markdown]
# ## Learning
#
# Let's now define functions to `train()` and `validate()` the model.

# %%
def train(epoch, log_interval=200):
    # Set model to training mode
    model.train()
    
    # Loop over each batch from the training set
    for batch_idx, (data, target) in enumerate(train_loader):
        # Copy data to GPU if needed
        data = data.to(device)
        target = target.to(device)

        # Zero gradient buffers
        optimizer.zero_grad() 
        
        # Pass data through the network
        output = model(data)

        # Calculate loss
        loss = criterion(output, target)

        # Backpropagate
        loss.backward()
        
        # Update weights
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

# %%
def validate(loss_vector, accuracy_vector):
    model.eval()
    val_loss, correct = 0, 0
    for data, target in validation_loader:
        data = data.to(device)
        target = target.to(device)
        output = model(data)
        val_loss += criterion(output, target).data.item()
        pred = output.data.max(1)[1] # get the index of the max log-probability
        correct += pred.eq(target.data).cpu().sum()

    val_loss /= len(validation_loader)
    loss_vector.append(val_loss)

    accuracy = 100. * correct.to(torch.float32) / len(validation_loader.dataset)
    accuracy_vector.append(accuracy)
    
    print('\nValidation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        val_loss, correct, len(validation_loader.dataset), accuracy))

# %% [markdown]
# Now we are ready to train our model using the `train()` function.  An *epoch* means one pass through the whole training data. After each epoch, we evaluate the model using `validate()`.

# %%
# %%time
epochs = 100

lossv, accv = [], []
for epoch in range(1, epochs + 1):
    train(epoch, log_interval=2000)
    validate(lossv, accv)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.293232
#
# Validation set: Average loss: 1.8726, Accuracy: 3217/10000 (32%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.888239
#
# Validation set: Average loss: 1.7695, Accuracy: 3729/10000 (37%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.779536
#
# Validation set: Average loss: 1.7149, Accuracy: 3886/10000 (39%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 2.060032
#
# Validation set: Average loss: 1.6935, Accuracy: 3950/10000 (40%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.919610
#
# Validation set: Average loss: 1.6626, Accuracy: 4150/10000 (42%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.706232
#
# Validation set: Average loss: 1.6323, Accuracy: 4204/10000 (42%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.581681
#
# Validation set: Average loss: 1.5980, Accuracy: 4303/10000 (43%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.766328
#
# Validation set: Average loss: 1.6006, Accuracy: 4363/10000 (44%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.753399
#
# Validation set: Average loss: 1.5835, Accuracy: 4395/10000 (44%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.874997
#
# Validation set: Average loss: 1.5647, Accuracy: 4495/10000 (45%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.451620
#
# Validation set: Average loss: 1.5651, Accuracy: 4394/10000 (44%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.709065
#
# Validation set: Average loss: 1.5470, Accuracy: 4532/10000 (45%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 1.615123
#
# Validation set: Average loss: 1.5302, Accuracy: 4615/10000 (46%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.168551
#
# Validation set: Average loss: 1.5501, Accuracy: 4483/10000 (45%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 1.450624
#
# Validation set: Average loss: 1.4962, Accuracy: 4731/10000 (47%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 1.460254
#
# Validation set: Average loss: 1.4989, Accuracy: 4753/10000 (48%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 1.573052
#
# Validation set: Average loss: 1.5118, Accuracy: 4705/10000 (47%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 1.651903
#
# Validation set: Average loss: 1.4875, Accuracy: 4705/10000 (47%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 1.513479
#
# Validation set: Average loss: 1.4873, Accuracy: 4754/10000 (48%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 1.447337
#
# Validation set: Average loss: 1.5091, Accuracy: 4651/10000 (47%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 1.574416
#
# Validation set: Average loss: 1.4734, Accuracy: 4787/10000 (48%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 1.621908
#
# Validation set: Average loss: 1.4677, Accuracy: 4824/10000 (48%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 1.394146
#
# Validation set: Average loss: 1.4896, Accuracy: 4773/10000 (48%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 1.532581
#
# Validation set: Average loss: 1.4770, Accuracy: 4750/10000 (48%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 1.488178
#
# Validation set: Average loss: 1.4736, Accuracy: 4722/10000 (47%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 1.561072
#
# Validation set: Average loss: 1.4573, Accuracy: 4860/10000 (49%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 1.329188
#
# Validation set: Average loss: 1.4956, Accuracy: 4632/10000 (46%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 1.582534
#
# Validation set: Average loss: 1.4543, Accuracy: 4908/10000 (49%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 1.406764
#
# Validation set: Average loss: 1.4598, Accuracy: 4816/10000 (48%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 1.493353
#
# Validation set: Average loss: 1.4460, Accuracy: 4931/10000 (49%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 1.466044
#
# Validation set: Average loss: 1.4506, Accuracy: 4901/10000 (49%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 1.753590
#
# Validation set: Average loss: 1.4601, Accuracy: 4852/10000 (49%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 1.477956
#
# Validation set: Average loss: 1.4525, Accuracy: 4826/10000 (48%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 1.543877
#
# Validation set: Average loss: 1.4402, Accuracy: 4941/10000 (49%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 1.440834
#
# Validation set: Average loss: 1.4558, Accuracy: 4851/10000 (49%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 1.467536
#
# Validation set: Average loss: 1.4377, Accuracy: 4941/10000 (49%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 1.662861
#
# Validation set: Average loss: 1.4351, Accuracy: 4909/10000 (49%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 1.565423
#
# Validation set: Average loss: 1.4377, Accuracy: 4917/10000 (49%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 1.563774
#
# Validation set: Average loss: 1.4440, Accuracy: 4840/10000 (48%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 1.932648
#
# Validation set: Average loss: 1.4210, Accuracy: 5002/10000 (50%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 1.057501
#
# Validation set: Average loss: 1.4461, Accuracy: 4908/10000 (49%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 1.121815
#
# Validation set: Average loss: 1.4493, Accuracy: 4850/10000 (48%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 1.573067
#
# Validation set: Average loss: 1.4273, Accuracy: 4963/10000 (50%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 1.345296
#
# Validation set: Average loss: 1.4431, Accuracy: 4837/10000 (48%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 1.373664
#
# Validation set: Average loss: 1.4127, Accuracy: 5013/10000 (50%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 1.487940
#
# Validation set: Average loss: 1.4261, Accuracy: 4945/10000 (49%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 1.707621
#
# Validation set: Average loss: 1.4132, Accuracy: 4993/10000 (50%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 1.166560
#
# Validation set: Average loss: 1.4269, Accuracy: 4948/10000 (49%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 1.458070
#
# Validation set: Average loss: 1.4294, Accuracy: 4960/10000 (50%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 1.340693
#
# Validation set: Average loss: 1.4270, Accuracy: 4968/10000 (50%)
#
# Train Epoch: 51 [0/50000 (0%)]	Loss: 1.393476
#
# Validation set: Average loss: 1.4091, Accuracy: 5034/10000 (50%)
#
# Train Epoch: 52 [0/50000 (0%)]	Loss: 1.311745
#
# Validation set: Average loss: 1.4254, Accuracy: 5041/10000 (50%)
#
# Train Epoch: 53 [0/50000 (0%)]	Loss: 1.495264
#
# Validation set: Average loss: 1.4069, Accuracy: 5058/10000 (51%)
#
# Train Epoch: 54 [0/50000 (0%)]	Loss: 1.554702
#
# Validation set: Average loss: 1.4292, Accuracy: 4962/10000 (50%)
#
# Train Epoch: 55 [0/50000 (0%)]	Loss: 1.725632
#
# Validation set: Average loss: 1.4300, Accuracy: 4955/10000 (50%)
#
# Train Epoch: 56 [0/50000 (0%)]	Loss: 1.259510
#
# Validation set: Average loss: 1.4229, Accuracy: 4977/10000 (50%)
#
# Train Epoch: 57 [0/50000 (0%)]	Loss: 1.429149
#
# Validation set: Average loss: 1.4000, Accuracy: 5016/10000 (50%)
#
# Train Epoch: 58 [0/50000 (0%)]	Loss: 1.063781
#
# Validation set: Average loss: 1.4354, Accuracy: 4932/10000 (49%)
#
# Train Epoch: 59 [0/50000 (0%)]	Loss: 1.110689
#
# Validation set: Average loss: 1.4223, Accuracy: 4995/10000 (50%)
#
# Train Epoch: 60 [0/50000 (0%)]	Loss: 1.615197
#
# Validation set: Average loss: 1.4133, Accuracy: 4997/10000 (50%)
#
# Train Epoch: 61 [0/50000 (0%)]	Loss: 1.434437
#
# Validation set: Average loss: 1.4256, Accuracy: 4972/10000 (50%)
#
# Train Epoch: 62 [0/50000 (0%)]	Loss: 1.202646
#
# Validation set: Average loss: 1.4273, Accuracy: 4924/10000 (49%)
#
# Train Epoch: 63 [0/50000 (0%)]	Loss: 1.349809
#
# Validation set: Average loss: 1.4352, Accuracy: 4963/10000 (50%)
#
# Train Epoch: 64 [0/50000 (0%)]	Loss: 1.472125
#
# Validation set: Average loss: 1.4057, Accuracy: 5000/10000 (50%)
#
# Train Epoch: 65 [0/50000 (0%)]	Loss: 1.479098
#
# Validation set: Average loss: 1.4008, Accuracy: 5069/10000 (51%)
#
# Train Epoch: 66 [0/50000 (0%)]	Loss: 1.253559
#
# Validation set: Average loss: 1.4403, Accuracy: 4877/10000 (49%)
#
# Train Epoch: 67 [0/50000 (0%)]	Loss: 1.019008
#
# Validation set: Average loss: 1.4085, Accuracy: 5044/10000 (50%)
#
# Train Epoch: 68 [0/50000 (0%)]	Loss: 1.170659
#
# Validation set: Average loss: 1.4288, Accuracy: 4952/10000 (50%)
#
# Train Epoch: 69 [0/50000 (0%)]	Loss: 1.753065
#
# Validation set: Average loss: 1.4231, Accuracy: 4954/10000 (50%)
#
# Train Epoch: 70 [0/50000 (0%)]	Loss: 1.212975
#
# Validation set: Average loss: 1.4359, Accuracy: 4844/10000 (48%)
#
# Train Epoch: 71 [0/50000 (0%)]	Loss: 1.301473
#
# Validation set: Average loss: 1.4207, Accuracy: 5032/10000 (50%)
#
# Train Epoch: 72 [0/50000 (0%)]	Loss: 1.252257
#
# Validation set: Average loss: 1.4301, Accuracy: 4963/10000 (50%)
#
# Train Epoch: 73 [0/50000 (0%)]	Loss: 1.313703
#
# Validation set: Average loss: 1.4462, Accuracy: 4923/10000 (49%)
#
# Train Epoch: 74 [0/50000 (0%)]	Loss: 1.386951
#
# Validation set: Average loss: 1.4519, Accuracy: 4890/10000 (49%)
#
# Train Epoch: 75 [0/50000 (0%)]	Loss: 1.138444
#
# Validation set: Average loss: 1.4095, Accuracy: 5117/10000 (51%)
#
# Train Epoch: 76 [0/50000 (0%)]	Loss: 1.130874
#
# Validation set: Average loss: 1.4092, Accuracy: 5032/10000 (50%)
#
# Train Epoch: 77 [0/50000 (0%)]	Loss: 1.231951
#
# Validation set: Average loss: 1.4178, Accuracy: 4980/10000 (50%)
#
# Train Epoch: 78 [0/50000 (0%)]	Loss: 1.469042
#
# Validation set: Average loss: 1.4091, Accuracy: 5069/10000 (51%)
#
# Train Epoch: 79 [0/50000 (0%)]	Loss: 1.544472
#
# Validation set: Average loss: 1.4063, Accuracy: 5012/10000 (50%)
#
# Train Epoch: 80 [0/50000 (0%)]	Loss: 1.562315
#
# Validation set: Average loss: 1.4057, Accuracy: 5059/10000 (51%)
#
# Train Epoch: 81 [0/50000 (0%)]	Loss: 1.388692
#
# Validation set: Average loss: 1.4122, Accuracy: 4959/10000 (50%)
#
# Train Epoch: 82 [0/50000 (0%)]	Loss: 1.465145
#
# Validation set: Average loss: 1.4101, Accuracy: 4984/10000 (50%)
#
# Train Epoch: 83 [0/50000 (0%)]	Loss: 1.204578
#
# Validation set: Average loss: 1.4096, Accuracy: 5044/10000 (50%)
#
# Train Epoch: 84 [0/50000 (0%)]	Loss: 1.326472
#
# Validation set: Average loss: 1.4117, Accuracy: 5009/10000 (50%)
#
# Train Epoch: 85 [0/50000 (0%)]	Loss: 1.367472
#
# Validation set: Average loss: 1.4213, Accuracy: 5004/10000 (50%)
#
# Train Epoch: 86 [0/50000 (0%)]	Loss: 1.493282
#
# Validation set: Average loss: 1.4026, Accuracy: 4978/10000 (50%)
#
# Train Epoch: 87 [0/50000 (0%)]	Loss: 1.362832
#
# Validation set: Average loss: 1.4313, Accuracy: 4910/10000 (49%)
#
# Train Epoch: 88 [0/50000 (0%)]	Loss: 1.334028
#
# Validation set: Average loss: 1.4284, Accuracy: 4983/10000 (50%)
#
# Train Epoch: 89 [0/50000 (0%)]	Loss: 1.238583
#
# Validation set: Average loss: 1.4600, Accuracy: 4905/10000 (49%)
#
# Train Epoch: 90 [0/50000 (0%)]	Loss: 1.093329
#
# Validation set: Average loss: 1.4028, Accuracy: 5090/10000 (51%)
#
# Train Epoch: 91 [0/50000 (0%)]	Loss: 1.035924
#
# Validation set: Average loss: 1.4245, Accuracy: 4950/10000 (50%)
#
# Train Epoch: 92 [0/50000 (0%)]	Loss: 1.446151
#
# Validation set: Average loss: 1.4027, Accuracy: 5071/10000 (51%)
#
# Train Epoch: 93 [0/50000 (0%)]	Loss: 1.509400
#
# Validation set: Average loss: 1.4172, Accuracy: 4992/10000 (50%)
#
# Train Epoch: 94 [0/50000 (0%)]	Loss: 1.207840
#
# Validation set: Average loss: 1.4150, Accuracy: 4979/10000 (50%)
#
# Train Epoch: 95 [0/50000 (0%)]	Loss: 1.135555
#
# Validation set: Average loss: 1.4123, Accuracy: 5047/10000 (50%)
#
# Train Epoch: 96 [0/50000 (0%)]	Loss: 1.389888
#
# Validation set: Average loss: 1.4436, Accuracy: 4863/10000 (49%)
#
# Train Epoch: 97 [0/50000 (0%)]	Loss: 1.287447
#
# Validation set: Average loss: 1.4244, Accuracy: 4941/10000 (49%)
#
# Train Epoch: 98 [0/50000 (0%)]	Loss: 1.375939
#
# Validation set: Average loss: 1.4525, Accuracy: 4872/10000 (49%)
#
# Train Epoch: 99 [0/50000 (0%)]	Loss: 1.524178
#
# Validation set: Average loss: 1.4137, Accuracy: 5023/10000 (50%)
#
# Train Epoch: 100 [0/50000 (0%)]	Loss: 1.062213
#
# Validation set: Average loss: 1.4584, Accuracy: 4885/10000 (49%)
#
# CPU times: user 17min 24s, sys: 3min 11s, total: 20min 36s
# Wall time: 19min 39s

# %% [markdown]
# ## Profiling the model

# %%
from thop import profile
import sys
sys.path.append('../bibd')
from bibd_layer import BibdLinear


def count_model(model, x, y):
    total_ops = np.sum(self.mask)

    model.total_ops += torch.Tensor([int(total_ops)])

input = torch.randn(3, 32, 32)
# print(input)
flops, params = profile(model, inputs=(input, ), custom_ops={BibdLinear: count_model})
print('Params(M): %.2f, FLOPs(G): %.2f' % params / (1000 ** 2), flops / (1000 ** 3))
# Out:
# Register FLOP counter for module Linear(in_features=3072, out_features=56, bias=True)
# Register FLOP counter for module Dropout(p=0.2, inplace=False)
# Register FLOP counter for module BibdLinear()
# Register FLOP counter for module Linear(in_features=49, out_features=10, bias=True)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-c70ddf29cd89> in <module>
#      12 input = torch.randn(3, 32, 32)
#      13 # print(input)
# ---> 14 flops, params = profile(model, inputs=(input, ), custom_ops={BibdLinear: count_model})
#      15 print('Params(M): %.2f, FLOPs(G): %.2f' % params / (1000 ** 2), flops / (1000 ** 3))
#
# ~/anaconda3/envs/iid2019_project_env/lib/python3.7/site-packages/thop/profile.py in profile(model, inputs, custom_ops, verbose)
#      90
#      91     with torch.no_grad():
# ---> 92         model(*inputs)
#      93
#      94     total_ops = 0
#
# ~/anaconda3/envs/iid2019_project_env/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-5-abc7ee6ca48d> in forward(self, x)
#      16     def forward(self, x):
#      17         x = x.view(-1, 3*32*32)
# ---> 18         x = F.relu(self.fc1(x))
#      19         x = self.fc1_drop(x)
#      20         x = F.relu(self.bibd2(x))
#
# ~/anaconda3/envs/iid2019_project_env/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/iid2019_project_env/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/anaconda3/envs/iid2019_project_env/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# RuntimeError: Expected object of device type cuda but got device type cpu for argument #2 'mat1' in call to _th_addmm
